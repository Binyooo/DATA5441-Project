# %% [markdown]
# # Exploratory Data Analysis
# The following notebook contains the exploratory data analysis of the first dataset used, PrimeKG for bipartite drug-disease link prediction.

# %% [markdown]
# # Loading the dataset

# %%
import pandas as pd
import networkx as nx
import graph_tool as gt
